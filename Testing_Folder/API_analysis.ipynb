# %%
# Import required libraries
from path import Path
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pybaseball import batting_stats
from pybaseball import batting_stats_range
from pybaseball import pitching_stats_range
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %% [markdown]
# ### Analysing *batting_stats()* with different paramters

# %%
all_data_2019 = batting_stats(2019)

# %%
print(str(int(all_data_2019["Season"][0])))

# %%
all_data_2019[["Name","Team"]]

# %%
all_data_2019 = batting_stats(2019)
players_with_more_than_50 = batting_stats(2019, qual=50)
all_data_since_2015 = batting_stats(2015, 2019)
aggregated_data = batting_stats(2010, 2016, ind=0)

print(all_data_2019.head())
print(players_with_more_than_50.head())
print(all_data_since_2015.head())
print(aggregated_data.head())

# %% [markdown]
# # Conclusion for batting_stats()
# Very versitile function that can take one or two years as parameters (single season or multiple seasons). It would return a dataframe with 287 columns with all the batting statistics for every single player for the whole season/seasons. A lot of statistics!
#
# ### Analysing *schedule_and_record()*

# %%
from pybaseball import schedule_and_record

Astros_record = schedule_and_record(2019, "HOU")
Astros_record.head(20)
# Out:
#                  Date   Tm Home_Away  Opp   W/L     R   RA  Inn   W-L  Rank  \
# 1    Thursday, Mar 28  HOU         @  TBR     W   5.0  1.0  9.0   1-0   2.0
# 2      Friday, Mar 29  HOU         @  TBR     L   2.0  4.0  9.0   1-1   2.0
# 3    Saturday, Mar 30  HOU         @  TBR     L   1.0  3.0  9.0   1-2   3.0
# 4      Sunday, Mar 31  HOU         @  TBR     L   1.0  3.0  9.0   1-3   4.0
# 5       Monday, Apr 1  HOU         @  TEX     W   2.0  1.0  9.0   2-3   4.0
# 6      Tuesday, Apr 2  HOU         @  TEX     L   4.0  6.0  9.0   2-4   4.0
# 7    Wednesday, Apr 3  HOU         @  TEX     L   0.0  4.0  9.0   2-5   4.0
# 8       Friday, Apr 5  HOU      Home  OAK     W   3.0  2.0  9.0   3-5   4.0
# 9     Saturday, Apr 6  HOU      Home  OAK     W   6.0  0.0  9.0   4-5   4.0
# 10      Sunday, Apr 7  HOU      Home  OAK  W-wo   9.0  8.0  9.0   5-5   2.0
# 11      Monday, Apr 8  HOU      Home  NYY     W   4.0  3.0  9.0   6-5   2.0
# 12     Tuesday, Apr 9  HOU      Home  NYY     W   6.0  3.0  9.0   7-5   2.0
# 13  Wednesday, Apr 10  HOU      Home  NYY     W   8.0  6.0  9.0   8-5   2.0
# 14     Friday, Apr 12  HOU         @  SEA     W  10.0  6.0  9.0   9-5   2.0
# 15   Saturday, Apr 13  HOU         @  SEA     W   3.0  1.0  9.0  10-5   2.0
# 16     Sunday, Apr 14  HOU         @  SEA     W   3.0  2.0  9.0  11-5   2.0
# 17    Tuesday, Apr 16  HOU         @  OAK     W   9.0  1.0  9.0  12-5   1.0
# 18  Wednesday, Apr 17  HOU         @  OAK     L   1.0  2.0  9.0  12-6   1.0
# 19     Friday, Apr 19  HOU         @  TEX     W   7.0  2.0  9.0  13-6   1.0
# 20   Saturday, Apr 20  HOU         @  TEX     L   4.0  9.0  9.0  13-7   2.0
#
#         GB        Win       Loss      Save  Time D/N  Attendance  Streak  \
# 1      1.0  Verlander      Snell      None  2:38   D     25025.0       1
# 2      1.0     Morton       Cole  Alvarado  2:38   N     13059.0      -1
# 3      2.0    Glasnow     McHugh  Alvarado  2:40   N     16010.0      -2
# 4      3.0   Chirinos      Miley  Castillo  2:12   D     18473.0      -3
# 5      3.0    Peacock    Sampson     Osuna  2:39   N     18056.0       1
# 6      4.0     Kelley     Valdez   Leclerc  3:23   N     17907.0      -1
# 7      4.5      Minor       Cole      None  2:39   N     22265.0      -2
# 8      3.5     McHugh     Montas     Osuna  3:03   N     43165.0       1
# 9      3.5      Miley     Brooks      None  2:47   N     34487.0       2
# 10     3.5      Osuna    Treinen      None  3:39   D     34902.0       3
# 11     3.5    Pressly   Ottavino     Osuna  2:59   N     27631.0       4
# 12     3.5     Rondon      Green     Osuna  3:15   N     31009.0       5
# 13     3.5     McHugh     Paxton   Pressly  3:30   N     27685.0       6
# 14     3.0    Peacock  Armstrong     Osuna  3:22   N     30972.0       7
# 15     2.0  Verlander  Hernandez     Osuna  2:46   N     30538.0       8
# 16     1.0       Cole    Brennan     Osuna  2:40   D     29242.0       9
# 17  up 0.5     McHugh    Estrada      None  3:03   N     12270.0      10
# 18  up 0.5     Montas      Miley   Treinen  2:29   N     11323.0      -1
# 19    Tied  Verlander      Smyly      None  3:16   N     35649.0       1
# 20     1.0     Kelley       Cole      None  2:51   N     39636.0      -1
#
#    Orig. Scheduled
# 1             None
# 2             None
# 3             None
# 4             None
# 5             None
# 6             None
# 7             None
# 8             None
# 9             None
# 10            None
# 11            None
# 12            None
# 13            None
# 14            None
# 15            None
# 16            None
# 17            None
# 18            None
# 19            None
# 20            None

# %%
Astros_record.columns

# %% [markdown]
# ### Conclusion for schedule_and_record()
# Very useful function that can get the players who played in each game, and also all the dates in which each a team played in a season, among others. It only has 19 columns, but this will be used as a *link* table between the others.
#
# ## Analysing *batting_stats_range()*

# %%
data_range = batting_stats_range("2019-09-01","2019-09-30")
data_range

# %%
print(data_range.columns)
print(all_data_2019.columns)

# %% [markdown]
# ### Conclusion for *batting_stats_range()*
#
# this functions returns a much smaller dataframe with only 27 columns. This will be useful to get the most recent information for each player right before each game.
#
# # Let's look at all the columns for batting_stats() and batting_stats_range()

# %%
print(all_data_2019.columns[:95])

# %%
print(all_data_2019.columns[95:190])

# %%
print(all_data_2019.columns[190:])

# %%
len(all_data_2019.columns)

# %%
len(data_range.columns)

# %% [markdown]
# ### Let's see what columns in the smaller dataframe are also in the larger df

# %%
shared_columns = list(data_range.columns & all_data_2019.columns)

# %%
shared_columns

# %%
len(shared_columns)

# %% [markdown]
# ### basically all of them. Only 4 are not included. Let's see which one are not in the larger df.

# %%
range_columns_not_in_all_data = list(data_range.columns.difference(all_data_2019.columns))
range_columns_not_in_all_data

# %% [markdown]
# # So #days is a useless column, BA is the same as AVG, Lev is useless too, and Tm is the same as Team. As a conclusion, all the columns are included.

# %%
Astros_2019stats  =  all_data_2019[all_data_2019["Team"]=="Astros"]

# %%
Astros_2019stats.count()

# %%
#Thursday, Mar 28
#"2019-03-28"
game_march_28_2019 = batting_stats_range("2019-03-28",)

# %%
game_march_28_2019["Tm"].unique

# %%
game_march_28_2019[game_march_28_2019["Tm"]=="Houston"]

# %% [markdown]
# ## ...We can see who played in every game ^

# %%
game_march_28_2019.columns

# %%
game_march_28_2019.iloc[:,6]

# %% [markdown]
# ### *"@"* means they're playing as *visitors*.

# %% [markdown]
# # Startegy:
# ### General Strategy:
# Retrieve data for each player in each game played. Feed the model with data from past year for each player and past month. Build a dataframe where each row represents the features to train the model and to make predictions out of the model.
#
# Each row would have the full 283 features from past season plus the 23 from past month for each player that played the particular game plus 2 team features.
#
# ### Specific Tasks
#
# Usually there are 9 players, so there would be 9 times 283 features only to account for past season statistics of 1 team. So this number would be later mulitply also by 2 since each game involves 2 teams. We will use **schedule_and_record()** function to get the players who played in a game, so we can later use **batting_stats()** function to get those 283 features from last season for each player that played a particular game.
#
# There will be also recent statistics from last month for each player as well, which is 22 features. Again this number would be multiply by 9 and then by 2. We will use **schedule_and_record()** function to get the players who played in that game, so we can later retrieve the past month statistics for each one of those players from **batting_stats_range()**.
#
# There will be also statistics from the team to be included in each record such as streak, and GB, also gotten from **schedule_and_record()**.
#
# ### Conclusion
# The training DataFrame will contain a record for each game of a single team and its opponent. This leads us to  **DataFrame with dimensions of 5494 columns by *Games-Played-By-The-Team* rows**. This is only batting statistics so far.

# %% [markdown]
# ## Analysing *pitching_stats()*

# %%
from pybaseball import pitching_stats

pitching_stats_2019 = pitching_stats("2019")
pitching_stats_2019.head(15)

# %%
pitching_stats_2019.columns

# %%
pitching_stats_2019.columns[:100]

# %%
pitching_stats_2019.columns[100:200]

# %%
pitching_stats_2019.columns[200:]

# %% [markdown]
# ### Aparanetly, we should use only the *(pi)* variables. They are calculated using a new algorythm that eliminates what Brooks Baseball considers errors from Pitch FX (pfx).
#
# link: https://www.reddit.com/r/Sabermetrics/comments/6qepoa/what_is_the_data_source_for_nonattributed_plate/

# %%
pfx_col = [x for x in pitching_stats_2019.columns if "(pfx)" in x ]
pfx_col

# %%
pitching_stats_2019.drop( columns = pfx_col, inplace=True )
pitching_stats_2019.columns

# %%
from pybaseball import pitching_stats_range

pitching_range_1day = pitching_stats_range("2019-03-28",)

# %%
pitching_range_1day.head()

# %%
pitchers_Astros_on_20190328 = pitching_range_1day[pitching_range_1day.Tm == "Houston"]
pitchers_Astros_on_20190328

# %% [markdown]
# ## So! we can know who pitched on a certain game ^

# %%
pitchers_Astros_on_20190328.columns

# %% [markdown]
# #### An idea is to keep columns that represent % of other columns. For example, keeping IFFB% but droping IFFB, since a percentage tells more of a story that an isolated scalar value. In this way, we can reduce redundancy in our features and, therefore, the total size of our features array.

# %%
bat_col_not_to_drop = [x for x in all_data_2019.columns if "%" in x and x[:-1] in all_data_2019.columns]
bat_col_not_to_drop

# %%
bat_col_to_drop = [x[:-1] for x in bat_col_not_to_drop]
bat_col_to_drop

# %%
pitch_col_not_to_drop = [x for x in pitching_stats_2019.columns if "%" in x and x[:-1] in pitching_stats_2019.columns]
pitch_col_not_to_drop

# %%
pitch_col_to_drop = [x[:-1] for x in pitch_col_not_to_drop]
pitch_col_to_drop

# %%
all_data_2019.drop(columns=bat_col_to_drop, inplace=True)
pitching_stats_2019.drop(columns=pitch_col_to_drop, inplace=True)
print(f"Total columns in bat_statistics: {len(all_data_2019.columns)}\nTotal columns in pitch_statistics: {len(pitching_stats_2019.columns)} ")

# %% [markdown]
# ### ...We still have loooots of columns.
#
#
# ##### We will have to get rid of some columns manually that we consider unnecesary such as "Age" or "Team", etc. However, some of these columns might be useful during concatenation, so we will handle this in within the function that creates the dataframe.
#
# ## Let's explore how many pitcher there are per game usually

# %%
# let's grab our datframe created through record_and_schedule() previously for The Astros season 2019:
Astros_record.head()

# %% [markdown]
# ### We will have to convert the date format cuz these guys are assholes

# %%
date = Astros_record.Date[1]
#date = date.split(",")
date = re.findall(r"\w* [0-9][0-9]|[0-9]", date)
date = date[0]
print(date)
year = "2019"
date = year + " " + date
date

# %%
import datetime as dt

# %%
date_formatted = dt.datetime.strptime(date,"%Y %b %d")
date_formatted

# %%
date_formatted.month

# %% [markdown]
# ### it worked out, so now we know how

# %%
type(date_formatted)

# %% [markdown]
# # %%%%%%%    Building the Training DataFrame    %%%%%%%%

# %%
# Import required libraries
from path import Path
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pybaseball import batting_stats
from pybaseball import batting_stats_range
from pybaseball import pitching_stats_range
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from pybaseball import schedule_and_record
import re
from pybaseball import pitching_stats
import datetime as dt

# %%
team_dict = {'Angels':'LAA',
            'Athletics': 'OAK',
            'Astros': 'HOU',
            'Braves': 'ATL',
            'Brewers': 'MIL',
            'Cards': 'STL',
            'Cubs': 'CHC',
            'Diamondbacks': 'ARI',
            'Dodgers': 'LAD',
            'Giants': 'SFG',
            'Indians': 'CLE',
            'Blue Jays': 'TOR',
            'Mariners': 'SEA',
            'Marlins': 'MIA',
            'Mets': 'NYM',
            'Nats': 'WSN',
            'Orioles': 'BAL',
            'Padres': 'SDP',
            'Phillies': 'PHI',
            'Pirates': 'PIT',
            'Rangers': 'TEX',
            'Rays': 'TBR',
            'Red Sox': 'BOS',
            'Reds': 'CIN',
            'Rockies': 'COL',
            'Royals': 'KCR',
            'Tigers': 'DET',
            'Twins': 'MIN',
            'White_Sox': 'CHW',
            'Yankees': 'NYY'
             
           }
def get_key_from_dict(dictionary, val): 
    for key, value in dictionary.items(): 
         if val == value: 
            return key

# %%
"""
Not necesary anymore.
"""
def switch_key_val_dict(dictionary): 
    new_dict = {}
    
    for key, value in dictionary.items():
        new_dict.update({value:key})
    
    return new_dict

# %%
acr_team_dict = {}
acr_team_dict.update({'CHC':'CUB'})
#acr_team_dict.update({'LAD':'LAD'})
acr_team_dict.update({'SFG':'SFO'})
acr_team_dict.update({'SDP':'SDG'})
acr_team_dict.update({'TBR':'TAM'} )
acr_team_dict.update({'KCR':'KAN'})
acr_team_dict.update({'CHW':'CWS'})
print(acr_team_dict.keys())
# Out:
# dict_keys(['CHC', 'SFG', 'SDP', 'TBR', 'KCR', 'CHW'])

# %%
def format_dates_to_dt(un_date="Monday, Dec 31", year=1999):
    date = re.findall(r"\W\w\w\w\s\d+", un_date)
    date = date[0]
    date = str(year) + date
    date_formatted = dt.datetime.strptime(date,"%Y %b %d")
    return date_formatted

# %%
def modify_dates_from_lineups(date="1. Thu,3/29 at TEX W (4-1)#", year = 2018):
    date = re.findall(r"\d+/\d+", date)
    try: date = date[0]
    except: return
    date = str(year) +" " + date
    return date

# %%
def modify_date_col_from_lineups(df, year):
    df["0"] = df.apply(lambda x: modify_dates_from_lineups(x["0"],year), axis=1)
    df["0"] = pd.to_datetime(df["0"])
    return df

# %%
def clean_lineups(df):
    
#Version 2: Find unique names and replace them by the desired
#format all at once instead of replacing one single name at a time in the table.

#convert manually portion of df in a list to later get unique names through set()
    rows = []
    for row in range(0,len(df)):
        temp = [*df.iloc[row,2:11]]
        for x in temp:
            rows.append(x)
            
    #finding the different unique names in the df        
    original_names = set(rows)
    
    #Replacing all the cells that share the same name with the desired format all at once
    #to avoid unnecesary repetition of the work going cell by cell spliting and replacing. 
    for name in original_names:
        real_name = name.split("-")
        real_name = real_name[0]
        df.replace(name,real_name, inplace=True)
        
    return df  
"""
After running time tests, v2 showed superiority by far in performance:
#################################################################

Time version 2:

114 ms ± 1.48 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
Time version 0:

4.07 s ± 80.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
def clean_lineups_v0(df):


#v0. Original version
    for row in range(0,len(df)):
        for column in range(2,11):
            original_name = df.iloc[row,column]
            name = original_name.split("-")
            name = name[0]
            df.replace(original_name,name, inplace=True)
            #WE CAN IMPROVE THIS LATER so we don't need to iterate all the dataframe since most of it
            #has the same names over and over. We just need to grab all the different names and replace them
   
    return df
    
    """
# Out:
# '\nAfter running time tests, v2 showed superiority by far in performance:\n#################################################################\n\nTime version 2:\n\n114 ms ± 1.48 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)\nTime version 0:\n\n4.07 s ± 80.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)\ndef clean_lineups_v0(df):\n\n\n#v0. Original version\n    for row in range(0,len(df)):\n        for column in range(2,11):\n            original_name = df.iloc[row,column]\n            name = original_name.split("-")\n            name = name[0]\n            df.replace(original_name,name, inplace=True)\n            #WE CAN IMPROVE THIS LATER so we don\'t need to iterate all the dataframe since most of it\n            #has the same names over and over. We just need to grab all the different names and replace them\n   \n    return df\n    \n    '

# %%
def format_lineups_df(df, year):
    df  =  modify_date_col_from_lineups(df, year)
    #print("Time version 2:\n")
    #%timeit d_f1 = clean_lineups(df)
    d_f1 = clean_lineups(df)
    #print("Time version 0:\n")
    #%timeit d_f2 = clean_lineups_v0(df)
    d_f1.columns = ["index","Date","1","2","3","4","5","6","7","8","9"]
    d_f1.set_index("index", inplace=True, drop=True)
    return df

# %%
"""
teamx = "HOU"
yearx = 2018
lineups_path = Path(f"Lineups/{teamx}_lineups_{yearx}.csv")
all_lineups_season = pd.read_csv(lineups_path)
all_lineups_season = format_lineups_df(all_lineups_season, yearx)
"""
"""
Time version 2:

114 ms ± 1.48 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
Time version 0:

4.07 s ± 80.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
"""
# Out:
# '\nTime version 2:\n\n114 ms ± 1.48 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)\nTime version 0:\n\n4.07 s ± 80.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)\n'

# %%
def get_dates_played(df=None,year=None):
    
    dates_played = [format_dates_to_dt(date, year) for date in df.Date]
    return dates_played

# %%
def get_team_schedule(year=None, team = "HOU"):
    
    try: teams_df  = schedule_and_record(year, team)
    except: 
        message: "Not able to get_team_schedule()"
        print(message)
        return message
    teams_df  = teams_df.iloc[ : , [0,1,2,3,4,10,17] ]
    teams_df["Date"] = teams_df.apply(lambda x: format_dates_to_dt(x["Date"],year), axis=1)
    teams_df.replace("@",1, inplace=True)
    teams_df.replace("Home",0, inplace=True)
    return teams_df

# %%
def get_players_per_game(year = None, team = None, line_ups_dict = None):
    
    
    
    schedule_df = get_team_schedule(year, team)
    if(type(schedule_df)=="str"): return schedule_df
    else: print(f"Dates played by {team} downloaded successfully...")
    
   
  
    opponents = set(schedule_df["Opp"])
    
    bat_stat_path = Path(f"../Data/Batting/Clean_Data/clean_batting_data_{year}.csv")
    all_bat_stats = pd.read_csv(bat_stat_path)
    
    pitchers_path = Path(f"Starting_Pitchers/Starting_Pitchers_{year}.csv")
    starting_pitchers = pd.read_csv(pitchers_path)
    #print(f"head of PITCHER STATS: \n{starting_pitchers.head()}")
    
    if line_ups_dict == None:
        
        lineups_path = Path(f"Lineups/{team}_lineups_{year}.csv")
        all_lineups_season = pd.read_csv(lineups_path)
        all_lineups_season = format_lineups_df(all_lineups_season, year)

        opponents_lineups = {}
        for opponent in opponents:
            opp_lineups_path = Path(f"Lineups/{opponent}_lineups_{year}.csv")
            opp_all_lineups_season = pd.read_csv(opp_lineups_path)
            #print(f"Reading CSV for: {opponent} successfully....")
            opp_all_lineups_season = format_lineups_df(opp_all_lineups_season, year)
            opponents_lineups.update({opponent:opp_all_lineups_season})
    else:
        all_lineups_season = line_ups_dict[team]
        
        opponents_lineups = {}
        for opponent in opponents:
            opponents_lineups.update({opponent:line_ups_dict[opponent]})
            
            
    
    players_df = pd.DataFrame()
    
    i = 0
    for date in schedule_df["Date"]:
        
        
        adversary = schedule_df[schedule_df["Date"]==date.strftime("%Y-%m-%d")]["Opp"].values[0]
        
        
        
        temp_dict = {"Date":date}

        ##Line ups for the team
        try: all_players_on_date = all_lineups_season[all_lineups_season["Date"]==date.strftime("%Y-%m-%d")]
            
        except:
            print(f"No game on this date {date} for team")
            continue
            
        count = 1  
        #print(f"ALL PLAYERS ON DATE:\n{all_players_on_date}")
        if len(all_players_on_date)==0: continue
        else: 
            all_players_team = all_players_on_date.iloc[0]
            for player in all_players_team[1:]:            
                temp_dict.update({f"player_{count:02}" : player})           
                count+=1
        
        ##Line ups for the adversary
        try:
            opp_lineups_df = opponents_lineups[adversary]
            all_opponents_on_date = opp_lineups_df[opp_lineups_df["Date"]==date.strftime("%Y-%m-%d")]
            all_opponents_on_date.columns = ["Date","10","11","12","12","14","15","16","17","18"]
        except:
            print(f"No game on this date {date} for opponent")
            continue

        count = 10  
        if len(all_opponents_on_date)==0: continue
        else: 
            all_players_opp = all_opponents_on_date.iloc[0]       
            for enemy in all_players_opp[1:]:            
                temp_dict.update({f"player_{count:02}" : enemy})           
                count+=1
         
        pitcher_on_date = starting_pitchers[starting_pitchers["Date"]==date.strftime("%Y-%m-%d")]
        #print(f"PITCHERS ON DATE: \n{pitcher_on_date}")    
        if team in acr_team_dict.keys():
                team = acr_team_dict[team]
        
        try:
            team_pitcher = pitcher_on_date[pitcher_on_date["Team"]==team]["PITCHER"].values[0]
            #print(f"TEAM PITCHER: \n{team_pitcher}")   
            temp_dict.update({"pitcher_team": team_pitcher })
        except:
            opponent_pitcher = "Unknown"
            print(f"No pitcher found for {team} on {date}")
            
        
        if adversary in acr_team_dict.keys(): 
            
            adversary = acr_team_dict[adversary]
        
        try:
            opponent_pitcher = pitcher_on_date[pitcher_on_date["Team"]==adversary]["PITCHER"].values[0] 
            #print(f"OPPONENT PITCHER: \n{opponent_pitcher}") 
            temp_dict.update({"pitcher_opp": opponent_pitcher})
        except:
            print(f"No pitcher found for {adversary} on {date}")
            opponent_pitcher = "Unknown"
        
        temp_df = pd.DataFrame(temp_dict, index =[i])
        players_df = pd.concat([players_df,temp_df], axis=0, sort = True )
        i+=1
        
    schedule_df.drop_duplicates(inplace = True)
    schedule_df.set_index("Date", inplace=True)
    players_df.drop_duplicates(inplace = True)
    players_df.set_index("Date", inplace=True)
    
    teams_df = pd.concat([schedule_df,players_df], axis=1)
    teams_df.reset_index(inplace=True, drop=False)
    
    return teams_df

# %%
def get_col_explanation(col1,col2):
    print(f"column 1: {col1[:10]}\ncolumn2: {col2[:10]}")
    try: col1 = [x.split("_")[1] for x in col1 if x is not "index"]
    except: pass
    try: col2 = [x.split("_")[1] for x in col2 if x is not "index"]
    except: pass   
    print(f"column 1: {col1[:10]}\ncolumn2: {col2[:10]}")
    if(len(col1)>len(col2)):missing_col = list(set(col1).difference(set(col2)))
    else:missing_col = list(set(col2).difference(set(col1)))
    return missing_col

# %%
def stats_single_game_x_team(players=None, names_df = None, team=None, stats_df=None, 
                             counter=1, pitching_stats = False, opponent = False, warnings=False):
    
    all_players_team_stats = pd.DataFrame()
    
    if team in acr_team_dict.keys(): team = acr_team_dict[team]
        
    if str(players[0]) != "nan":
        for player in players:

                if("00:00:00" in str(player)): continue #If it's a date, Skip it.
                if "jr." in player: player = player[:-3]

                try: 
                    
                    current_team_players = names_df[names_df.Team==team]
                    player_full_name = [x for x in current_team_players.Name if player.lower() == x.split(" ")[1].lower() ]
                    if len(player_full_name)>1 and warnings: 
                        print(f"More than one player with this laste name \n{player_full_name}")
                    if len(player_full_name)==0: 
                    # If we couldn't find a player in current season, let's try finding him in stats from last year
                        player_full_name = [x for x in stats_df.Name if (player.lower() in x.lower()) &
                                           (stats_df[stats_df.Team==get_key_from_dict( team_dict ,team )])]
                        if warnings:
                            if len(player_full_name)==0: print(f"We couldn't find player {player}")
                            else: print(f"We found {player} in last year's stats")
                    #print(player_full_name)
                    player_stats = stats_df[stats_df.Name==player_full_name[0]]
                    if len(player_stats)==0: 
                        if warnings: print(f"couldn't find statistics for {player_full_name[0]}")
                    # If we couldn't find statistics x player let's iterate the array pf possible players
                        i=1
                        while (len(player_stats)==0):
                            player_stats = stats_df[stats_df.Name==player_full_name[i]] 
                            if len(player_stats)==1: 
                                if warnings: print(f"We found stats for {player_full_name[i]} instead.")
                            i+=1
                                
                        else: print(f"We found {player} in last year's stats")
                    if len(player_stats["Name"])>1 : 
                        if warnings: 
                            print("More than one player with same name")
                            print(player_stats)
                        player_stats = player_stats[player_stats.Team == get_key_from_dict( team_dict ,team )]
                   
                                        

                except Exception as e: 
                    if warnings: print(f"{player} from {get_key_from_dict( team_dict ,team )}, {team} not in list Pitcher? :{pitching_stats}. \nError: {e}")

                    try:
                        #nanlist = np.empty((1,len(player_stats.columns)))
                        nanlist = np.empty((1,len(stats_df.columns)))
                    except Exception as e:
                        if warnings: print(f"Not able to get columns from last player\n{e}")
                        continue
                    nanlist.fill(np.nan)
                    fake_columns = stats_df.columns
                    player_stats = pd.DataFrame(data = nanlist, columns = fake_columns)
                    #player_stats.drop(columns=["index"], inplace=True)

                new_col = []
                for col in player_stats.columns:
                    if pitching_stats: 
                        if opponent: new_col.append(f"opponet_pitcher_{col}")
                        else: new_col.append(f"team_pitcher_{col}")
                    else: new_col.append(f"{counter:02}_{col}")
                player_stats.columns = new_col
                player_stats.reset_index(inplace=True, drop=True)
                all_players_team_stats = pd.concat([ all_players_team_stats, player_stats ] ,   axis=1)

                counter+=1
                
    else:
        print(f"Received not a string as a player ({type(players)})\n{players}")
        try:
            nanlist = np.empty((1,len(stats_df.columns)))
        except Exception as e:
            print(f"Not able to get columns from last player\n{e}")
            return 
            
        nanlist.fill(np.nan)
        fake_columns = stats_df.columns
        player_stats = pd.DataFrame(data = nanlist, columns = fake_columns)
        
        new_col = []
        for col in player_stats.columns:
            if pitching_stats: 
                if opponent: new_col.append(f"opponet_pitcher_{col}")
                else: new_col.append(f"team_pitcher_{col}")
            else: new_col.append(f"{counter:02}_{col}")
        player_stats.columns = new_col
        player_stats.reset_index(inplace=True)
        all_players_team_stats = pd.concat([ all_players_team_stats, player_stats ] ,   axis=1)

        counter+=1

            
    return all_players_team_stats

# %%
def get_stats_startingplayer_by_game(players_df=None, team=None, batting_season_data=None,pitching_season_data=None, year=None, warnings=False):
    
    if batting_season_data.empty: batting_season_data = batting_stats(year-1)   
    if pitching_season_data.empty: pitching_season_data = pitching_stats(year-1)
    print("stats loaded")
    
    bat_names_path = Path(f"../Data/Batting/Clean_Data/clean_batting_data_{year}.csv")
    all_bat_names = pd.read_csv(bat_names_path)
    
    pitch_names_path = Path(f"../Data/Pitching/Clean_Data/clean_pitching_data_{year}.csv")
    all_pitch_names = pd.read_csv(pitch_names_path)
    #names_teams_current_season = batting_stats(year)
    #pitchers_teams_current_season = pitching_stats(year)    
    print("names loaded")
    
    names_teams_current_season = all_bat_names[["Date","Name","Tm"]]  
    names_teams_current_season.columns = ["Date","Name","Team"]
    #print(names_teams_current_season.head())
    pitchers_teams_current_season = all_pitch_names[["Date","Name","Tm"]]
    pitchers_teams_current_season.columns = ["Date","Name","Team"]
    #print(pitchers_teams_current_season.head())
    
    #print(pitching_season_data.head()) 
    
    stats_players_start_lineup = pd.DataFrame()
    print("starting concatenating df..")
    for row in range(0,len(players_df)):
        
        all_players_stats = pd.DataFrame()
       
        date_x=players_df.iloc[row][0]
        all_players_team_stats = stats_single_game_x_team(players = players_df.iloc[row][9:18],
                                                          names_df = names_teams_current_season[names_teams_current_season["Date"]==
                                                                                               date_x.strftime("%Y-%m-%d")],
                                                                  team = team, 
                                                                  stats_df = batting_season_data)
        
        #print("names_df for team pitchers:\n")
        #print(pitchers_teams_current_season[pitchers_teams_current_season["Date"]==date_x.strftime("%Y-%m-%d")])
        pitcher_team = stats_single_game_x_team(players = [players_df.iloc[row][8]],
                                                          names_df = pitchers_teams_current_season[pitchers_teams_current_season["Date"]==
                                                                                               date_x.strftime("%Y-%m-%d")],
                                                                  team = team, 
                                                                  stats_df = pitching_season_data,
                                                           pitching_stats = True)
        
        
        #print("names_df for opponent batters:\n")
        #print(names_teams_current_season[names_teams_current_season["Date"]==date_x.strftime("%Y-%m-%d")])  
        all_players_opp_stats = stats_single_game_x_team(players = players_df.iloc[row][18:], 
                                                       names_df = names_teams_current_season[names_teams_current_season["Date"]==
                                                                                               date_x.strftime("%Y-%m-%d")],
                                                                  team = players_df.iloc[row][3], 
                                                                  stats_df = batting_season_data,
                                                                  counter = 10)     
        
        #print("names_df for opponent pitchers:\n")
        #print(pitchers_teams_current_season[pitchers_teams_current_season["Date"]==date_x.strftime("%Y-%m-%d")])
        pitcher_opp = stats_single_game_x_team(players = [players_df.iloc[row][7]],
                                                          names_df = pitchers_teams_current_season[pitchers_teams_current_season["Date"]==
                                                                                               date_x.strftime("%Y-%m-%d")],
                                                                  team = players_df.iloc[row][3], 
                                                                  stats_df = pitching_season_data,
                                                           pitching_stats = True,
                                                           opponent = True)
        
        
        try:
            all_players_stats = pd.concat([ all_players_team_stats, 
                                           pitcher_team,
                                           all_players_opp_stats,
                                           pitcher_opp] ,  
                                          axis=1)   

        except Exception as e: 
            print(f"could not concatenate stats\n{e}")
            continue
            
        try: 
            stats_players_start_lineup = stats_players_start_lineup.append(all_players_stats, ignore_index=True)
        except Exception as e: 
            print(f"could not append {e}")
            print(f"explanation: \n{get_col_explanation(stats_players_start_lineup.columns,all_players_stats.columns)}")
            
            continue
        
    
    return stats_players_start_lineup

# %%
def get_col_contains(name=None, columns=None, split_criteria = "_"):
   # columns_processed = []
    try: 
        #columns_processed = [x.split(split_criteria)[1] for x in columns if x is not "index"]
        cols = [x for x in columns if name in x]
    except: pass
    return list(cols)

# %%
def create_trining_df(year = (dt.datetime.today().year-1), team = "HOU" , batting_season_data=None,
                      pitching_season_data=None, line_ups_dict = None):
                       
    
    if line_ups_dict == None:   players_df = get_players_per_game(year, team)
    else:                       players_df = get_players_per_game(year, team, line_ups_dict)
        
    if type(players_df)=="str": return players_df
    else: print(f"List of names for players from {team} for every game in {year} successfully created...")
    #print(players_df.tail(10))    
    
    stats_players_start_lineup = get_stats_startingplayer_by_game(players_df = players_df, 
                                                                  batting_season_data = batting_season_data,
                                                                  pitching_season_data = pitching_season_data,
                                                                  team =team, year = year)
    
    return pd.concat([players_df.iloc[:,[4,0,1,2,3,5,6]],stats_players_start_lineup], axis=1, join='inner')

# %%
def check_values_in_cols(val=np.nan,col_contains=None, df=None):
    
    cols = get_col_contains(name=col_contains, columns=df.columns)
    names_dataf = df[cols]
    if val==np.nan:
        narows=[index for index in range(0,len(names_dataf)) if
                names_dataf.iloc[index].isna().values.any()]
    else:
        narows=[index for index in range(0,len(names_dataf)) if
                (names_dataf.iloc[index]==val).any()]
    #print(f"NA Rows (total: {len(narows)}): \n{narows}\ntotal: {len(narows)}")
    return names_dataf.iloc[narows]

# %%
def clean_baseball_stats_df(data_frame=None):
  
    df = data_frame.copy()
    #set date as index
    try: df.set_index("Date", inplace=True, drop=True)
    except: 
        print("Could not set Date as index. Maybe it already is?")
        pass
    df.replace(np.nan, 0, inplace =True)
    
    df.replace("W-wo","W", inplace = True)
    df.replace("L-wo","L", inplace = True)
    #df[["W/L","GB"]].replace("W",1, inplace=True)
    #df[["W/L","GB"]].replace("L",0, inplace=True)
    
    #drop col with (pfx) as discovered in earlier.
    pfx_col = [x for x in df.columns if "(pfx)" in x ]
    
    #drop col with Age since they are not relevant.
    age_col = [x for x in df.columns if "Age" in x ]
    
    #drop col when they have scalars but others have the same expressed in percentage.
    col_not_to_drop = [x for x in df.columns if "%" in x and x[:-1] in df.columns]
    not_perc_col = [x[:-1] for x in col_not_to_drop]
    
    #Drop columns that have Name, index, Season 
    #name_cols = get_col_contains(name="Name", columns=df.columns)
    index_cols = get_col_contains(name="index", columns=df.columns)
    team_cols = get_col_contains(name="Team", columns=df.columns)
    Season_cols = get_col_contains(name="Season", columns=df.columns)
    
    #Drop columns Team, Opp
    specific_col = ["GB"]
    

    
    cols_to_drop =[ *pfx_col, *not_perc_col,*index_cols, *team_cols,
                   *Season_cols,*age_col,*specific_col]
    
    
    

    
    df.drop(columns=cols_to_drop, inplace=True)
    
    
    return df

# %%
def create_global_train_df(year=2019):
    
    #downlaoding the batting and pitching statistics from preveous year
    batting_season_data = batting_stats(year-1)   
    pitching_season_data = pitching_stats(year-1)
    print("Statistics downloaded successfully...")
    
    #reading line ups for every team in the year and storing it in a dictionary.
    line_ups_dict = {}
    
    for key, val in team_dict.items():
        
        lineups_path = Path(f"Lineups/{val}_lineups_{year}.csv")
        lineups_season = pd.read_csv(lineups_path)
        print(f"Reading CSV for: {val} successfully....")
        lineups_season = format_lineups_df(lineups_season, year)
        line_ups_dict.update({val:lineups_season})
    
    #creating the global training dataframe
    global_training_df = pd.DataFrame()
    for key, val in team_dict.items():
        print(val)
        training_df_team = create_trining_df(year=year, team = val,
                                             batting_season_data =  batting_season_data,
                                             pitching_season_data = pitching_season_data,
                                             line_ups_dict = line_ups_dict)
        
        if type( training_df_team )  ==  "str" : 
            print("Training Datframe failed. -----------\n\n")
            print( training_df_team ) 
            continue
        global_training_df = pd.concat([global_training_df,training_df_team], axis=0, sort =False)
        
    global_training_df.sort_index(axis=0,inplace=True)
    clean_global_df = global_training_df.copy()
    clean_global_df = clean_baseball_stats_df(clean_global_df)
    clean_global_df.sort_index(axis=0,inplace=True)
    
    return clean_global_df, global_training_df

# %%
def create_all_training_df(start_year,final_year):
    
    for year in range( start_year, final_year+1):
        
        global_training_df, raw_training_df = create_global_train_df(year)
        
        raw_training_df.set_index("Date", inplace = True)
        
        raw_path = Path(f"training_dataframes/raw_{year}.csv")
        raw_training_df.to_csv(raw_path)
        
        clean_path = Path(f"training_dataframes/clean_{year}.csv")
        global_training_df.to_csv(clean_path)

# %%
create_all_training_df(2017,2019)
# Out:
# Statistics downloaded successfully...
# Reading CSV for: LAA successfully....
# Reading CSV for: OAK successfully....
# Reading CSV for: HOU successfully....
# Reading CSV for: ATL successfully....
# Reading CSV for: MIL successfully....
# Reading CSV for: STL successfully....
# Reading CSV for: CHC successfully....
# Reading CSV for: ARI successfully....
# Reading CSV for: LAD successfully....
# Reading CSV for: SFG successfully....
# Reading CSV for: CLE successfully....
# Reading CSV for: TOR successfully....
# Reading CSV for: SEA successfully....
# Reading CSV for: MIA successfully....
# Reading CSV for: NYM successfully....
# Reading CSV for: WSN successfully....
# Reading CSV for: BAL successfully....
# Reading CSV for: SDP successfully....
# Reading CSV for: PHI successfully....
# Reading CSV for: PIT successfully....
# Reading CSV for: TEX successfully....
# Reading CSV for: TBR successfully....
# Reading CSV for: BOS successfully....
# Reading CSV for: CIN successfully....
# Reading CSV for: COL successfully....
# Reading CSV for: KCR successfully....
# Reading CSV for: DET successfully....
# Reading CSV for: MIN successfully....
# Reading CSV for: CHW successfully....
# Reading CSV for: NYY successfully....
# LAA
# Dates played by LAA downloaded successfully...
# List of names for players from LAA for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# OAK
# Dates played by OAK downloaded successfully...
# List of names for players from OAK for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# HOU
# Dates played by HOU downloaded successfully...
# List of names for players from HOU for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Adams in last year's stats
# We found Adams in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# ATL
# Dates played by ATL downloaded successfully...
# List of names for players from ATL for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# MIL
# Dates played by MIL downloaded successfully...
# List of names for players from MIL for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# STL
# Dates played by STL downloaded successfully...
# List of names for players from STL for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Adams in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# CHC
# Dates played by CHC downloaded successfully...
# List of names for players from CHC for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# ARI
# Dates played by ARI downloaded successfully...
# List of names for players from ARI for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Adams in last year's stats
# LAD
# Dates played by LAD downloaded successfully...
# List of names for players from LAD for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Adams in last year's stats
# SFG
# Dates played by SFG downloaded successfully...
# List of names for players from SFG for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# CLE
# Dates played by CLE downloaded successfully...
# List of names for players from CLE for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# TOR
# Dates played by TOR downloaded successfully...
# List of names for players from TOR for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# SEA
# Dates played by SEA downloaded successfully...
# List of names for players from SEA for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# MIA
# Dates played by MIA downloaded successfully...
# List of names for players from MIA for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# NYM
# Dates played by NYM downloaded successfully...
# List of names for players from NYM for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Adams in last year's stats
# We found Adams in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Adams in last year's stats
# WSN
# Dates played by WSN downloaded successfully...
# List of names for players from WSN for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# BAL
# Dates played by BAL downloaded successfully...
# List of names for players from BAL for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# SDP
# Dates played by SDP downloaded successfully...
# List of names for players from SDP for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Adams in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# PHI
# Dates played by PHI downloaded successfully...
# List of names for players from PHI for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Adams in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# PIT
# Dates played by PIT downloaded successfully...
# List of names for players from PIT for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# TEX
# Dates played by TEX downloaded successfully...
# List of names for players from TEX for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# TBR
# Dates played by TBR downloaded successfully...
# List of names for players from TBR for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# BOS
# Dates played by BOS downloaded successfully...
# List of names for players from BOS for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# CIN
# Dates played by CIN downloaded successfully...
# List of names for players from CIN for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Adams in last year's stats
# We found Adams in last year's stats
# COL
# Dates played by COL downloaded successfully...
# List of names for players from COL for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Adams in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# KCR
# Dates played by KCR downloaded successfully...
# List of names for players from KCR for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Frazier in last year's stats
# DET
# Dates played by DET downloaded successfully...
# List of names for players from DET for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# MIN
# Dates played by MIN downloaded successfully...
# List of names for players from MIN for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Frazier in last year's stats
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Frazier in last year's stats
# CHW
# Dates played by CHW downloaded successfully...
# List of names for players from CHW for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# NYY
# Dates played by NYY downloaded successfully...
# List of names for players from NYY for every game in 2017 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# We found Frazier in last year's stats
# Statistics downloaded successfully...
# Reading CSV for: LAA successfully....
# Reading CSV for: OAK successfully....
# Reading CSV for: HOU successfully....
# Reading CSV for: ATL successfully....
# Reading CSV for: MIL successfully....
# Reading CSV for: STL successfully....
# Reading CSV for: CHC successfully....
# Reading CSV for: ARI successfully....
# Reading CSV for: LAD successfully....
# Reading CSV for: SFG successfully....
# Reading CSV for: CLE successfully....
# Reading CSV for: TOR successfully....
# Reading CSV for: SEA successfully....
# Reading CSV for: MIA successfully....
# Reading CSV for: NYM successfully....
# Reading CSV for: WSN successfully....
# Reading CSV for: BAL successfully....
# Reading CSV for: SDP successfully....
# Reading CSV for: PHI successfully....
# Reading CSV for: PIT successfully....
# Reading CSV for: TEX successfully....
# Reading CSV for: TBR successfully....
# Reading CSV for: BOS successfully....
# Reading CSV for: CIN successfully....
# Reading CSV for: COL successfully....
# Reading CSV for: KCR successfully....
# Reading CSV for: DET successfully....
# Reading CSV for: MIN successfully....
# Reading CSV for: CHW successfully....
# Reading CSV for: NYY successfully....
# LAA
# Dates played by LAA downloaded successfully...
# List of names for players from LAA for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# OAK
# Dates played by OAK downloaded successfully...
# List of names for players from OAK for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# HOU
# Dates played by HOU downloaded successfully...
# List of names for players from HOU for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# ATL
# Dates played by ATL downloaded successfully...
# List of names for players from ATL for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# MIL
# Dates played by MIL downloaded successfully...
# List of names for players from MIL for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'pandas.core.series.Series'>)
# player_01    NaN
# player_02    NaN
# player_03    NaN
# player_04    NaN
# player_05    NaN
# player_06    NaN
# player_07    NaN
# player_08    NaN
# player_09    NaN
# Name: 162, dtype: object
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'pandas.core.series.Series'>)
# player_10    NaN
# player_11    NaN
# player_12    NaN
# player_13    NaN
# player_14    NaN
# player_15    NaN
# player_16    NaN
# player_17    NaN
# player_18    NaN
# Name: 162, dtype: object
# Received not a string as a player (<class 'list'>)
# [nan]
# could not append Plan shapes are not aligned
# column 1: Index(['01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB', '01_PA',
#        '01_H', '01_1B', '01_2B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# STL
# Dates played by STL downloaded successfully...
# List of names for players from STL for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Garcia in last year's stats
# We found Garcia in last year's stats
# We found Garcia in last year's stats
# We found Garcia in last year's stats
# We found Garcia in last year's stats
# We found Garcia in last year's stats
# CHC
# Dates played by CHC downloaded successfully...
# List of names for players from CHC for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'pandas.core.series.Series'>)
# player_01    NaN
# player_02    NaN
# player_03    NaN
# player_04    NaN
# player_05    NaN
# player_06    NaN
# player_07    NaN
# player_08    NaN
# player_09    NaN
# Name: 162, dtype: object
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'pandas.core.series.Series'>)
# player_10    NaN
# player_11    NaN
# player_12    NaN
# player_13    NaN
# player_14    NaN
# player_15    NaN
# player_16    NaN
# player_17    NaN
# player_18    NaN
# Name: 162, dtype: object
# Received not a string as a player (<class 'list'>)
# [nan]
# could not append Plan shapes are not aligned
# column 1: Index(['01_+WPA', '01_-WPA', '01_1B', '01_2B', '01_3B', '01_AB', '01_AVG',
#        '01_Age', '01_Age Rng', '01_BABIP'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['+WPA', '-WPA', '1B', '2B', '3B', 'AB', 'AVG', 'Age', 'Age Rng', 'BABIP']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# ARI
# Dates played by ARI downloaded successfully...
# List of names for players from ARI for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# LAD
# Dates played by LAD downloaded successfully...
# List of names for players from LAD for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'pandas.core.series.Series'>)
# player_01    NaN
# player_02    NaN
# player_03    NaN
# player_04    NaN
# player_05    NaN
# player_06    NaN
# player_07    NaN
# player_08    NaN
# player_09    NaN
# Name: 162, dtype: object
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'pandas.core.series.Series'>)
# player_10    NaN
# player_11    NaN
# player_12    NaN
# player_13    NaN
# player_14    NaN
# player_15    NaN
# player_16    NaN
# player_17    NaN
# player_18    NaN
# Name: 162, dtype: object
# Received not a string as a player (<class 'list'>)
# [nan]
# could not append Plan shapes are not aligned
# column 1: Index(['01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB', '01_PA',
#        '01_H', '01_1B', '01_2B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# SFG
# Dates played by SFG downloaded successfully...
# List of names for players from SFG for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# CLE
# Dates played by CLE downloaded successfully...
# List of names for players from CLE for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# TOR
# Dates played by TOR downloaded successfully...
# List of names for players from TOR for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# SEA
# Dates played by SEA downloaded successfully...
# List of names for players from SEA for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# MIA
# Dates played by MIA downloaded successfully...
# List of names for players from MIA for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Garcia in last year's stats
# NYM
# Dates played by NYM downloaded successfully...
# List of names for players from NYM for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# WSN
# Dates played by WSN downloaded successfully...
# List of names for players from WSN for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Garcia in last year's stats
# BAL
# Dates played by BAL downloaded successfully...
# List of names for players from BAL for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# SDP
# Dates played by SDP downloaded successfully...
# List of names for players from SDP for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# PHI
# Dates played by PHI downloaded successfully...
# List of names for players from PHI for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# PIT
# Dates played by PIT downloaded successfully...
# List of names for players from PIT for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Garcia in last year's stats
# We found Garcia in last year's stats
# TEX
# Dates played by TEX downloaded successfully...
# List of names for players from TEX for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# TBR
# Dates played by TBR downloaded successfully...
# List of names for players from TBR for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# BOS
# Dates played by BOS downloaded successfully...
# List of names for players from BOS for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# CIN
# Dates played by CIN downloaded successfully...
# List of names for players from CIN for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# We found Garcia in last year's stats
# COL
# Dates played by COL downloaded successfully...
# List of names for players from COL for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'pandas.core.series.Series'>)
# player_01    NaN
# player_02    NaN
# player_03    NaN
# player_04    NaN
# player_05    NaN
# player_06    NaN
# player_07    NaN
# player_08    NaN
# player_09    NaN
# Name: 162, dtype: object
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'pandas.core.series.Series'>)
# player_10    NaN
# player_11    NaN
# player_12    NaN
# player_13    NaN
# player_14    NaN
# player_15    NaN
# player_16    NaN
# player_17    NaN
# player_18    NaN
# Name: 162, dtype: object
# Received not a string as a player (<class 'list'>)
# [nan]
# could not append Plan shapes are not aligned
# column 1: Index(['01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB', '01_PA',
#        '01_H', '01_1B', '01_2B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# KCR
# Dates played by KCR downloaded successfully...
# List of names for players from KCR for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# We found Garcia in last year's stats
# DET
# Dates played by DET downloaded successfully...
# List of names for players from DET for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# MIN
# Dates played by MIN downloaded successfully...
# List of names for players from MIN for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# CHW
# Dates played by CHW downloaded successfully...
# List of names for players from CHW for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# NYY
# Dates played by NYY downloaded successfully...
# List of names for players from NYY for every game in 2018 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Statistics downloaded successfully...
# Reading CSV for: LAA successfully....
# Reading CSV for: OAK successfully....
# Reading CSV for: HOU successfully....
# Reading CSV for: ATL successfully....
# Reading CSV for: MIL successfully....
# Reading CSV for: STL successfully....
# Reading CSV for: CHC successfully....
# Reading CSV for: ARI successfully....
# Reading CSV for: LAD successfully....
# Reading CSV for: SFG successfully....
# Reading CSV for: CLE successfully....
# Reading CSV for: TOR successfully....
# Reading CSV for: SEA successfully....
# Reading CSV for: MIA successfully....
# Reading CSV for: NYM successfully....
# Reading CSV for: WSN successfully....
# Reading CSV for: BAL successfully....
# Reading CSV for: SDP successfully....
# Reading CSV for: PHI successfully....
# Reading CSV for: PIT successfully....
# Reading CSV for: TEX successfully....
# Reading CSV for: TBR successfully....
# Reading CSV for: BOS successfully....
# Reading CSV for: CIN successfully....
# Reading CSV for: COL successfully....
# Reading CSV for: KCR successfully....
# Reading CSV for: DET successfully....
# Reading CSV for: MIN successfully....
# Reading CSV for: CHW successfully....
# Reading CSV for: NYY successfully....
# LAA
# Dates played by LAA downloaded successfully...
# List of names for players from LAA for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# OAK
# Dates played by OAK downloaded successfully...
# List of names for players from OAK for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# HOU
# Dates played by HOU downloaded successfully...
# No pitcher found for HOU on 2019-05-10 00:00:00
# List of names for players from HOU for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# ATL
# Dates played by ATL downloaded successfully...
# List of names for players from ATL for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# MIL
# Dates played by MIL downloaded successfully...
# List of names for players from MIL for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# STL
# Dates played by STL downloaded successfully...
# List of names for players from STL for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# CHC
# Dates played by CHC downloaded successfully...
# List of names for players from CHC for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# ARI
# Dates played by ARI downloaded successfully...
# List of names for players from ARI for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# LAD
# Dates played by LAD downloaded successfully...
# List of names for players from LAD for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# SFG
# Dates played by SFG downloaded successfully...
# List of names for players from SFG for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# CLE
# Dates played by CLE downloaded successfully...
# List of names for players from CLE for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# TOR
# Dates played by TOR downloaded successfully...
# List of names for players from TOR for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# SEA
# Dates played by SEA downloaded successfully...
# List of names for players from SEA for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# MIA
# Dates played by MIA downloaded successfully...
# List of names for players from MIA for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# NYM
# Dates played by NYM downloaded successfully...
# List of names for players from NYM for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# WSN
# Dates played by WSN downloaded successfully...
# List of names for players from WSN for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# BAL
# Dates played by BAL downloaded successfully...
# List of names for players from BAL for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# SDP
# Dates played by SDP downloaded successfully...
# List of names for players from SDP for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# PHI
# Dates played by PHI downloaded successfully...
# List of names for players from PHI for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# PIT
# Dates played by PIT downloaded successfully...
# List of names for players from PIT for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# TEX
# Dates played by TEX downloaded successfully...
# No pitcher found for HOU on 2019-05-10 00:00:00
# List of names for players from TEX for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# TBR
# Dates played by TBR downloaded successfully...
# List of names for players from TBR for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# BOS
# Dates played by BOS downloaded successfully...
# No pitcher found for BOS on 2019-08-07 00:00:00
# No pitcher found for KAN on 2019-08-07 00:00:00
# List of names for players from BOS for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# could not append Plan shapes are not aligned
# column 1: Index(['01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB', '01_PA',
#        '01_H', '01_1B', '01_2B'],
#       dtype='object')
# column2: Index(['01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB', '01_PA',
#        '01_H', '01_1B', '01_2B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# CIN
# Dates played by CIN downloaded successfully...
# List of names for players from CIN for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# COL
# Dates played by COL downloaded successfully...
# List of names for players from COL for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# KCR
# Dates played by KCR downloaded successfully...
# No pitcher found for KAN on 2019-08-07 00:00:00
# No pitcher found for BOS on 2019-08-07 00:00:00
# List of names for players from KCR for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# Received not a string as a player (<class 'list'>)
# [nan]
# Received not a string as a player (<class 'list'>)
# [nan]
# could not append Plan shapes are not aligned
# column 1: Index(['01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB', '01_PA',
#        '01_H', '01_1B', '01_2B'],
#       dtype='object')
# column2: Index(['01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB', '01_PA',
#        '01_H', '01_1B', '01_2B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# DET
# Dates played by DET downloaded successfully...
# List of names for players from DET for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# MIN
# Dates played by MIN downloaded successfully...
# List of names for players from MIN for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# CHW
# Dates played by CHW downloaded successfully...
# List of names for players from CHW for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..
# NYY
# Dates played by NYY downloaded successfully...
# List of names for players from NYY for every game in 2019 successfully created...
# stats loaded
# names loaded
# starting concatenating df..

# %%
#changing all WAS for WSN in pitching stats
#changing all LOS for LAD in pitching stats

"""
import pandas as pd
from pathlib import Path
stats =[]
for year in range(2019,2020):
    path = Path(f"Starting_Pitchers/Starting_Pitchers_{year}.csv")
    pitch_stats = pd.read_csv(path)
    pitch_stats.replace("WAS","WSN", inplace=True)
    pitch_stats.to_csv(path)
    stats.append(pitch_stats)

for df in stats:
    print(df.head(20))
   """
#changing 2019 faulty year label

"""

def change_2017_to_2019(date):
    old_date = date.split("-")
    new_date = '2019'+"-"+old_date[1]+"-"+old_date[2]
    return new_date

import pandas as pd
from pathlib import Path

path = Path(f"Starting_Pitchers/Starting_Pitchers_2019.csv")
pitch_stats = pd.read_csv(path)
pitch_stats["Date"] = pitch_stats.apply(lambda x: change_2017_to_2019(x["Date"]), axis = 1)
#pitch_stats["Date"] = pd.to_datetime(pitch_stats["Date"])
    
pitch_stats.to_csv(path)

    """
# Out:
# '\n\ndef change_2017_to_2019(date):\n    old_date = date.split("-")\n    new_date = \'2019\'+"-"+old_date[1]+"-"+old_date[2]\n    return new_date\n\nimport pandas as pd\nfrom pathlib import Path\n\npath = Path(f"Starting_Pitchers/Starting_Pitchers_2019.csv")\npitch_stats = pd.read_csv(path)\npitch_stats["Date"] = pitch_stats.apply(lambda x: change_2017_to_2019(x["Date"]), axis = 1)\n#pitch_stats["Date"] = pd.to_datetime(pitch_stats["Date"])\n    \npitch_stats.to_csv(path)\n\n    '

# %%
clean_path = Path(f"training_dataframes/clean_2019.csv")
df_2019 = pd.read_csv(clean_path)
set(df_2019["W/L"])
# Out:
# {'L', 'W'}

# %%
df_2019[["W/L", "Streak"]]
# Out:
#      W/L  Streak
# 0      L      -1
# 1      W       1
# 2      L      -2
# 3      W       2
# 4      L      -1
# 5      L      -1
# 6      W       1
# 7      W       1
# 8      W       1
# 9      W       1
# 10     L      -1
# 11     L      -1
# 12     L      -1
# 13     W       1
# 14     W       1
# 15     W       3
# 16     L      -1
# 17     W       1
# 18     W       1
# 19     L      -1
# 20     L      -1
# 21     W       1
# 22     W       1
# 23     W       1
# 24     L      -1
# 25     L      -1
# 26     L      -1
# 27     L      -1
# 28     L      -1
# 29     L      -1
# ...   ..     ...
# 4826   L      -2
# 4827   L      -1
# 4828   L      -1
# 4829   W       5
# 4830   L      -6
# 4831   W       7
# 4832   L      -1
# 4833   L      -5
# 4834   W       8
# 4835   W       3
# 4836   L      -1
# 4837   W       2
# 4838   W       1
# 4839   L      -3
# 4840   W       1
# 4841   W       3
# 4842   L      -2
# 4843   W       1
# 4844   L      -1
# 4845   L      -3
# 4846   L      -3
# 4847   W       2
# 4848   L      -2
# 4849   W       3
# 4850   L      -1
# 4851   L      -3
# 4852   L      -1
# 4853   W       1
# 4854   W       2
# 4855   L      -2
#
# [4856 rows x 2 columns]
